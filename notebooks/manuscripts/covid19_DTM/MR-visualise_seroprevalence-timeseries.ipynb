# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from covid19_DTM.data.sciensano import get_serological_data
from covid19_DTM.visualization.output import *

# %%
# first inspect the syntax of the raw data

herzog_raw = pd.read_csv("../../../data/covid19_DTM/raw/sero/serology_covid19_belgium_round_1_to_7_v20210406.csv", parse_dates=['collection_start', 'collection_end'])
sciensano_raw = pd.read_csv("../../../data/covid19_DTM/raw/sero/Belgium COVID-19 Studies - Sciensano_Blood Donors_Tijdreeks.csv")

# %%
# Note that this raw data is NOT used, rather the interim data is used, which is a copy of Table S1 in the work by Herzog et al. 2021
sciensano_raw
# Out:
#             Date  Lower CI  Upper CI  Seroprevalence
# 0    18 Mar 2020       NaN       NaN             NaN
# 1    30 Mar 2020     0.006     0.035           0.020
# 2    16 Apr 2020     0.035     0.066           0.053
# 3    29 Apr 2020     0.034     0.067           0.050
# 4    13 May 2020     0.036     0.072           0.053
# 5    27 May 2020     0.038     0.074           0.055
# 6    10 Jun 2020     0.030     0.061           0.045
# 7    24 Jun 2020     0.043     0.078           0.059
# 8     7 Jul 2020     0.040     0.078           0.058
# 9    23 Jul 2020     0.035     0.069           0.052
# 10    5 Aug 2020     0.031     0.066           0.048
# 11   19 Aug 2020     0.042     0.079           0.060
# 12   2 Sept 2020     0.030     0.069           0.049
# 13  16 Sept 2020     0.028     0.062           0.044
# 14  30 Sept 2020     0.030     0.069           0.048
# 15   14 Oct 2020     0.038     0.077           0.057
# 16   28 Oct 2020     0.068     0.120           0.092
# 17   11 Nov 2020     0.106     0.167           0.136
# 18   25 Nov 2020     0.131     0.203           0.164
# 19    9 Dec 2020     0.149     0.228           0.187
# 20   21 Dec 2020     0.155     0.245           0.196
# 21    6 Jan 2021     0.156     0.217           0.187
# 22   20 Jan 2021     0.160     0.228           0.194
# 23    2 Feb 2021     0.175     0.233           0.203
# 24    2 Mar 2021     0.214     0.299           0.256
# 25   30 Mar 2021     0.273     0.356           0.315
# 26   27 Apr 2021     0.412     0.503           0.456
# 27   25 May 2021     0.575     0.651           0.611
# 28   22 Jun 2021     0.759     0.815           0.787
# 29   20 Jul 2021     0.955     0.992           0.975
# 30    1 Aug 2021       NaN       NaN             NaN

# %%
df_sero_herzog, df_sero_sciensano = get_serological_data()

# %%
dates1 = df_sero_herzog.index.values
values1 = df_sero_herzog['rel', 'mean'].values
lower1 = df_sero_herzog['rel', 'LL'].values
upper1 = df_sero_herzog['rel', 'UL'].values

dates2 = df_sero_sciensano.index.values
values2 = df_sero_sciensano['rel', 'mean'].values
lower2 = df_sero_sciensano['rel', 'LL'].values
upper2 = df_sero_sciensano['rel', 'UL'].values

# %% [markdown]
# # Plot with nice colorframe

# %%
fig, ax = plt.subplots(figsize=(15, 3))

start_date = pd.Timestamp(2020, 1, 1)
end_date = pd.Timestamp(2022, 1, 1)

# Add mobility time series
ax.scatter(dates1, values1, color='maroon', zorder=4, label='Herzog et al.') # ambulatory patients (from doctor)
ax.fill_between(dates1, upper1, lower1, color='maroon', linewidth=2, zorder=4, alpha=0.20)
ax.scatter(dates2, values2, color='darkgreen', zorder=4, label='Sciensano', marker='x')
ax.fill_between(dates2, upper2, lower2, linewidth=2, color='darkgreen', zorder=4, alpha=0.20) # Red Cross donors

# Add background colouring
week_color='white'#'white'
weekend_color='white'#'lightgrey'
vacation_color='lightgrey'#weekend_color
color_timeframes(start_date, end_date, ax=ax, week_color=week_color, weekend_color=weekend_color, vacation_color=vacation_color)

ax.set_xlim(start_date, end_date)
plt.yscale('symlog', linthresh=0.1, subs=[2, 3, 4, 5, 6, 7, 8, 9], linscale=1.618)
ax.set_yticks([0.05, 0.1, 1])
ax.set_yticklabels([5, 10, 100])

ax.set_ylabel('Seroprevalence (%)')

ax.legend(loc=2)

ax.grid(False)

plt.savefig('seroprevalence-data_timeline.pdf', dpi=400, bbox_inches='tight')
